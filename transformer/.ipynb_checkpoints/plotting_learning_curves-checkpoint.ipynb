# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import glob as glob

# %%
file = "TRANSFORMER_SGD_LR_SCHEDULE_model=TRANSFORMER_optimizer=SGD_LR_SCHEDULE_initial_lr=20_batch_size=128_seq_len=35_hidden_size=512_num_layers=6_dp_keep_prob=0.9_save_best_1"
curves = np.load(file + "/learning_curves.npy")

# %%
curves[()]
# Out:
# {'train_ppls': [259291.42495923518,
#   10711.710290456307,
#   5035.2537543125345,
#   4074.44847469028,
#   3426.4380138587044,
#   3301.7622970411835,
#   1566.4767999517435,
#   1422.9967582928844,
#   1159.4350710401648,
#   850.1926104859127,
#   505.51180459951314,
#   429.9700745752804,
#   429.2255880871344,
#   430.34159300373375,
#   384.02309179588605,
#   285.44804457327893,
#   210.45846079030994,
#   161.9668512017914,
#   132.37157133498357,
#   116.00376896108106,
#   107.82545720525077,
#   104.07540305062426,
#   102.6558617963985,
#   102.11094391722334,
#   101.99133540264567,
#   101.93009632933297,
#   101.94483851285933,
#   101.88655428331907,
#   101.94277432382755,
#   101.90714605819169,
#   101.83071710670907,
#   101.86301733979975,
#   101.80701951822535,
#   101.90173123896778,
#   101.89568506606595,
#   101.96702496033787,
#   101.87224668616258,
#   101.8941518673467,
#   101.90926633631133,
#   101.9116688393877],
#  'val_ppls': [3185.94988297167,
# ...
